# %%
"""
Created on Monday Oct 12 2020

@Author: Mayank Taggar
"""

"""

  Docstring:

  A) Introduction:
  This game is based on saving the Time Continuum. All our timelines (past,present and future)
  have become interconnected and are working in an unlimited time loop. Dr. Roland wants to 
  manipulate this time and end the world as we know it. The user travels back in time to put an 
  end to Dr. Rolands evil plans.
  
  This game is inpired by a TV series called dark, watch the trailer to know more
  https://www.youtube.com/watch?v=mloCBq4tftQ

  Stage 1: Decide whether to play the game or not
  Stage 2: Enter code to continue to open a door
  Stage 3: Play a game of dice rolll with Antila
  Stage 4: Opening the door with a code
  Stage 5: A final face off with Dr.Roland.
  
  B) Known bugs and/or Errors:
  None

"""
import emoji

def intro():
    #making name a global oject
    global Name
    
    print(f"""{'**'*45}
    
 _  _  _         _                                 _______             ______                 _     
(_)(_)(_)       | |                               (_______)           (______)               | |    
 _  _  _  _____ | |   ____   ___   ____   _____       _      ___       _     _  _____   ____ | |  _ 
| || || || ___ || |  / ___) / _ \ |    \ | ___ |     | |    / _ \     | |   | |(____ | / ___)| |_/ )
| || || || ____|| | ( (___ | |_| || | | || ____|     | |   | |_| |    | |__/ / / ___ || |    |  _ ( 
 \_____/ |_____) \_) \____) \___/ |_|_|_||_____)     |_|    \___/     |_____/  \_____||_|    |_| \_ 

{'**'*45}
""")
    
    #A brief intro about the game.
    print("""
This is a game about time, we think that we have time but actually time controls us.
We are all connected, our past, our future, and aur present. All the actions are
inclufuenced by somthing. Deja Vu is nothing but a repetition of things that 
you have experiened in your future and now living in present

This game is about saving the world from apocalypse which is the master plan of 
Dr. Roland. He wants to destroy the continues infinite loop of time and create 
a loop hole to start a new cycle of life. 

You are from future and have seen the apocolypse happening, that will erase 
the mankind from this planet.
""")
    
    #Player inputs
    Name = input(prompt = "What do you wanna call yourself?\n")
    
    Name = Name.capitalize()

    print(f"""Welcome, {Name}! 
You are back in your own past. You have got this chance to save the world, 
you have to stop Dr. Ronald from causing the apocolypse 
""")

    #Asking user permision to start the game
    Answer = input(prompt = """Are you ready to save the world? 
Type yes or no """)
    
    #Remoning the user input errors
    Answer = Answer.lower().strip()
    
    #Starting aloop to prompt user for the correct answer
    while True:
        if Answer == 'yes'or 'y' == Answer:
            print(f"""
{Name}, you cannot turn back and disclose this mission to anyone. It is the most 
important mission and the entire world needs you now.
""")
            Mission_1()
            break
        
        elif Answer.lower().strip() == 'no'or 'n' == Answer.lower().strip():
            print(f"{Name}, you have failed the city.")
            fail()
            
        else:
             Answer = input(prompt = "Please type a yes or no").lower().strip()
               
    
   
    #Defining first mission for the user
def Mission_1():
    
    print(f"""{'**'*40}

{Name}, the first mission is to get information from Noah, he is 
an industrlist and has connection Dr.Roland. All the information he has is
in a red briefcase which is in a safe at the central Bank of Gonzola.""")
    
    input('::::: Press any key to continue :::::\n')
    
    print("""
You are now at the central Bank of Gonzola. We have the code for the
main entrance.""")
    
    while True:
        try:
            code = int(input(prompt = "Type in 456388 to enter the building."))
        
        except ValueError:
            code = int(input(prompt = "Please type in in 456388, carefully to enter the building."))
            continue
        
        if code == 456388:
            print(f"""
{Name}, you have now entered the bank, now you have to find the way to the vault.
But be prepare to face the most high tech security system in the world""")
            Mission_2()
            break
            
        else:
            code = input(prompt = "Please type 456388, or you will be dead\n")

#Defining the second mission
def Mission_2():
    
    print(f"""{'**'*40}
{Name}, you have now entered the bank and you have to get to the vault safely.
its time to get the red briefcase and get information on location of Dr. Roland
""")
    
    #Defining a new object Way
    Way = input(f"""
You see three articles on the reception of the bank, one of then will help you 
reach to vault safely or else you will fail the mission. 

a. Gun 
b. Map of the bank 
c. beer Mug
""")
 
    # converting guess using .lower()
    Way = Way.lower()
   
    #Nested contitional statement 
    if Way == 'a' or 'gun' in Way:
        print(f"""{Name} ,the gaurds are firing at you. Doge to left and now to the right
The bullets are coming.{'..'*20}

You have defeated the guards and reached to the vault. But you are injured, bleeding
badly and left with 50% of health left and losing health continuosly.""")
        
        Health = input(prompt = "Press the key 'H' to retrive a health boster. Hurry! else you will die.")
        
        #Starting a nested conditional
        if Health.lower().strip() == 'h':
            print("You have retrived you health and you its time to go to the next mission")
            Mission_3()
        
        else:
            fail()
              
    elif Way == 'b' or 'map' in Way or 'bank' in Way:
        print(f"""Congratulations {Name}, you have safely reached to the vault, now one step closer in
saving the city of Gonzola, lets go to the next mission""")
        Mission_3()
    
    elif Way == 'c' or 'coffee' in Way or 'mug' in Way:
        fail()
    
    else:
        Way = input(prompt = "Try again and type in the correct option to save the Gonzola city.")


def Mission_2():
    input('::::: Press any key to continue :::::\n')
    
    print(f"""{'**'*40}
    
{Name}, you have now reached the reached to the second mission, the word is out
that you are gonna save the world. But be aware Dr.Ronald have ears all around 
the city and is now aware that you want to stop his mission of destroying the world.

The only person that knows the cordinates of Dr.Rolans's lab is his girlfriend Antila. 
To take control of her mind you have to defeat her in rolling the dice game.""")
    
    input('::::: Press any key to continue :::::\n')
    
    print("""Antila is right now at a private club 'The Battery', go there and defeat 
her with your rolling skills. You only have three chances to defeat her, hurry!!!!""")

    input('::::: Press any key to continue :::::\n')
    
    #imprting the random dataframe
    import random
    
    #defining a function die
    die = random.randint(1, 6)

    #Defining total attemts for the user
    Attempt = 3
    
    #While loop to give chances to the user
    while Attempt>0:
        try:
            guess = int(input(prompt = """Guess a number between 1 to 6 that is gonna come when she roll
the dice.
"""))
        except ValueError:
            guess = int(input(prompt = """Guess a number between 1 to 6 that is gonna come when she roll
the dice.
"""))  
        #starting a conditional statement    
        if guess == die:
            print(f"""
{Name}, you have finally impressed Antila and now you can extract cordinates of Dr.Ronald's 
lab and stop the apocalypse.
""")
            Mission_3()
            break
        
        elif guess!= die:
            Attempt -= 1
            
            #Nested conditional statement
            if Attempt > 0:
                print(f"""
This is wrong, she is gaing power over your mind now. You have {Attempt} attempt remaining.\n""")
           
            elif Attempt ==0:
                print("""
Antila won the game, you have failed the city of Gonzola,
Start fro the last mission again.
""")
                Mission_2()
            
            else:
                print("Please type in a number between 1 to 6")
    
        else:
            print("Please type in a number between 1 to 6")



#Defining the third mission
def Mission_3():
    input('::::: Press any key to continue :::::\n')
    
    #A brief introduction of Mission 3
    print(f"""{'**'*40}
    
{Name}, you have now reached the reached to the third mission, the word is out that you are
gonna save the world. But be aware Dr.Ronald have ears all around the city and is now aware
that you want to stop his master plan.

We have recieved a information about a secret tunnel that leads to Dr.Ronald's labrotary, 
which he usses to acess the bank.""")

    input('::::: Press any key to continue :::::\n')
    
    print("""
Noah have proved to be an important asset again, he was able to get the code that
disables the security system in the tunnel and will lead you to Dr.Roland's Lab.
""")
    
    input('::::: Press any key to continue :::::\n')
    
    #Starting a while loop to propmt a user to type in the correct answer
    while True:
        Door_code = input(prompt = """Press the key 'D' to get the code from Trivedi. 
Hurry! the system will activate soon.
""")
        Door_code = Door_code.lower().strip()
        
        #Contitional statement to remove the input errors
        if Door_code == 'd':
            
            print("""
The security system have been disabled, you will now face Dr. Roland. This will
not be easy. But this is the prize to save the world. Hurry!!!!!!!
""")
            Mission_4()
            break
        
        else:
             Door_code = input(prompt = "Try again and press the key 'D'. Hurry! the system will activate soon.\n")
    
    input('::::: Press any key to continue :::::\n')
 

#defining the fourth function
def Mission_4():
    print(f"""
{Name} you have finnally reached in the last stage of defeating Dr. Roland and saving
the world from apocalypse. This round is very random like time. Nothing is in your control.

You will just have to continue as you cannot quit at this moment. Be strong,
the light is with you
""")
    
    #importing the random data frame
    import random

    #Defining objects
    player1=0
    player2=0
    player1wins=0
    player2wins=0
    rounds = 1
    
    #starting a while for rounds
    while rounds !=4:
        Fight_1 = random.randint(1,10)
        Fight_2 = random.randint(1,10)
        
        player1 = Fight_1
        player2 = Fight_2
        
        print("This is the round" + str(rounds))
        
        input('::::: Press any key to continue :::::\n')
       
        #Extending conditional statement
        if player1 == player2:
            print(f"{Name}, it is a draw game\n")       
        
        elif player2 > player1:
            player2wins += 1
            print("Dr. Roland have won this round\n")
           
        
        else:
            player1wins += 1
            print(f"{Name}, you have won this round\n")
        
        rounds += 1 


    #Contitinal statemnt to declare the winner
    if player1wins == player2wins:
        print(f"""
This is a draw game and the world is still in danger. {Name}, you have
to start the last mission again.
""")
        Mission_4()
    elif player1wins > player2wins:
        print(f"""{Name}, you have won the game.""")
        won()
        
    else:
        print("""
Dr. Roland have deafeted you and have won. The world will be destroyed in next
24 hours, wait you have one more chance.
""")
        fail()

        
#Defining a winning function
def won():
    
    print(f"""{'**'*40}
    
{Name}, you have finally defeated Dr. Roland and saved the world from being 
destroyed by Dr. Roland. The world thanks you.

 |   | |                (_)(_)(_)              | |
| |___| |  ___   _   _    _  _  _   ___   ____  | |
|_____  | / _ \ | | | |  | || || | / _ \ |  _ \ |_|
 _____| || |_| || |_| |  | || || || |_| || | | | _ 
(_______| \___/ |____/    \_____/  \___/ |_| |_||_|

{'**'*40}
""")
    
    #defining a new object
    newgame = input (prompt= """Are you ready to save the city from the apocolypse again?
Type yes or no """)
    
    #Removing the user input errors
    newgame = newgame.lower().strip()
    
    #Starting aloop to prompt user for the correct answer
    while True:
        if newgame =='yes'or 'y' == newgame:
            print(f"""
{Name}, you cannot turn back and disclose this mission to anyone. It is the most 
important mission and the entire city needs you now.
""")
            Mission_1()
            break
        
        elif newgame== 'no'or 'n' == newgame:
            exit(0)
    
        else:
             Answer = input(prompt = "Please type a yes or no\n")
    
 
 #Defining  fail function
def fail():
    from sys import exit
    
    print(f"""{'**'*40}
    
{Name}, you have failed and the world is dead, the only way to save the world 
is to play again and defeat Dr. Roland.
""")

    restart = input (prompt= """Are you ready to save the city from the apocolypse again?
Type yes or no """)
    
    #Removing the user input errors
    restart = restart.lower().strip()
    
    #Starting aloop to prompt user for the correct answer
    while True:
        if restart =='yes'or 'y' == restart:
            print(f"""
{Name}, you cannot turn back and disclose this mission to anyone. It is the most 
important mission and the entire city needs you now.
""")
            Mission_1()
            break
        
        elif restart== 'no'or 'n' == restart:
            print(f"""
{Name}, you have failed the city

(_______)                                                   
 _   ___  _____  ____   _____     ___   _   _  _____   ____ 
| | (_  |(____ ||    \ | ___ |   / _ \ | | | || ___ | / ___)
| |___) |/ ___ || | | || ____|  | |_| | \ V / | ____|| |    
 \_____/ \_____||_|_|_||_____)   \___/   \_/  |_____)|_| 
    
{'**'*40}
""")         
            
            exit(0)           
        
        else:
             Answer = input(prompt = "Please type a yes or no\n")

    
    
intro()
# Out:
# ******************************************************************************************
#
#  _  _  _         _                                 _______             ______                 _
# (_)(_)(_)       | |                               (_______)           (______)               | |
#  _  _  _  _____ | |   ____   ___   ____   _____       _      ___       _     _  _____   ____ | |  _
# | || || || ___ || |  / ___) / _ \ |    \ | ___ |     | |    / _ \     | |   | |(____ | / ___)| |_/ )
# | || || || ____|| | ( (___ | |_| || | | || ____|     | |   | |_| |    | |__/ / / ___ || |    |  _ (
#  \_____/ |_____) \_) \____) \___/ |_|_|_||_____)     |_|    \___/     |_____/  \_____||_|    |_| \_
#
# ******************************************************************************************
#
#
# This is a game about time, we think that we have time but actually time controls us.
# We are all connected, our past, our future, and aur present. All the actions are
# ...
